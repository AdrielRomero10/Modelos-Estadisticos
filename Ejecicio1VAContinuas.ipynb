# %% [markdown]
# # Equipo Sala 8
# **Ejercicio V.A. Continuas**
#
# ###Integrantes
# -	Alarcón Estrada Rodrigo German.
# -	Ravelo Buitrón Sofía.
# - Romero Cervantes Lizhet Adriel.

# %% [markdown]
# $\color{red}{\text{Ejercicio 1.}}$ Un alumno se dirige a la biblioteca para solicitar el préstamo de un libro y decide que no puede esperar más de $10$ minutos en ser atendido. Supongamos que el bibliotecario tarda por lo menos $0.5$ minutos en atender a una persona, entonces es razonable proponer una distribución uniforme en el intervalo $[0.5,10]$ para modelar el comportamiento de la variable $X$ que es el tiempo en ser atendido (en  minutos).
#
# - Da la función de densidad y gráfica.
# - ¿Cuál es la probabilidad de que el tiempo en ser atendido sea mayor a $5$ minutos pero menor a $8$ minutos?
# - ¿Cuál es la esperanza y varianza?
# - Calcula la función de distribución y gráficala, y con ella calcula: $\mathbb{P}(2.51\le X \le 7.99)$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# %%
# Parámetros de la distribución
a = 0.5   # mínimo
b = 10    # máximo
dist = uniform(loc=a, scale=b-a)  # Distribución U(0.5, 10)

# %%
x = np.linspace(a-1, b+1, 500)   # rango extendido
pdf = dist.pdf(x)

plt.figure(figsize=(6,4))
plt.plot(x, pdf, label="f(x)", color = 'r')
plt.fill_between(x, pdf, alpha=0.2)
plt.title("Función de Densidad Uniforme U[0.5, 10]")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# 4. Función de distribución y gráfica
cdf = dist.cdf(x)

plt.figure(figsize=(6,4))
plt.plot(x, cdf, label="F(x)", color="pink")
plt.title("Función de Distribución Acumulada U[0.5, 10]")
plt.xlabel("x")
plt.ylabel("F(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
p_interval = dist.cdf(7.99) - dist.cdf(2.51)
print("P(2.51 ≤ X ≤ 7.99) =", p_interval)
# Out:
# P(2.51 ≤ X ≤ 7.99) = 0.576842105263158

# %%
# Resultados

print("Resultados:")
print(f"1) Función de densidad: f(x) = 1/(b-a) = 1/{b-a:.2f} ≈ {1/(b-a):.4f}")
print(f"2) P(5 < X < 8) = {p_5_8:.4f}")
print(f"3) Esperanza = {esperanza:.4f}")
print(f"   Varianza  = {varianza:.4f}")
print(f"4) P(2.51 <= X <= 7.99) = {p_interval:.4f}")
# Out:
# Resultados:
# 1) Función de densidad: f(x) = 1/(b-a) = 1/9.50 ≈ 0.1053
# 2) P(5 < X < 8) = 0.3158
# 3) Esperanza = 5.2500
#    Varianza  = 7.5208
# 4) P(2.51 <= X <= 7.99) = 0.5768
